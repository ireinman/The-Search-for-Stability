# %%
from utils.k_effect_prp_converage_ratio_utils import *

# %% [markdown]
# ## Run simulation

# %%
run_prp_k_converge_comparison()

# %% [markdown]
# ## Results

# %% [markdown]
# ### PRP k covergence ratio comparison with $k \in [2, 10]$, $n=2$, $\lambda = 0.5$

# %%
load_prp_k_converge_comparison()
