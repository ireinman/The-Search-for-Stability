# %%
from utils.extra_simulations_utils import *

# %% [markdown]
# ## Run simulations

# %%
run_prp_rrp_n_comparison()

# %%
for ro1 in [0, 0.5, -0.5]:
    for ro2 in [0, 0.5, -0.5]:
        run_specific_ro_lam_comparison(ro1=ro1, ro2=ro2)

# %% [markdown]
# ## Results

# %% [markdown]
# ### n Comparison

# %%
load_n_comparison()

# %% [markdown]
# ### $\rho_1, \rho_2$ Comparison

# %%
load_specific_ro_lam_comparison(ro1=0, ro2=0)

# %%
load_specific_ro_lam_comparison(ro1=0, ro2=0.5)

# %%
load_specific_ro_lam_comparison(ro1=0, ro2=-0.5)

# %%
load_specific_ro_lam_comparison(ro1=0.5, ro2=0)

# %%
load_specific_ro_lam_comparison(ro1=0.5, ro2=0.5)

# %%
load_specific_ro_lam_comparison(ro1=0.5, ro2=-0.5)

# %%
load_specific_ro_lam_comparison(ro1=-0.5, ro2=0)

# %%
load_specific_ro_lam_comparison(ro1=-0.5, ro2=0.5)

# %%
load_specific_ro_lam_comparison(ro1=-0.5, ro2=-0.5)
