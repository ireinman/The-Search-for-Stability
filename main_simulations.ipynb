# %%
from utils.main_simulations_utils import *

# %% [markdown]
# ## Run simulations

# %%
run_prp_rrp_lam_comparison()

# %%
run_softmax_beta_comparison()

# %%
run_linear_slope_comparison()

# %% [markdown]
# ## Results

# %% [markdown]
# ### 1. PRP vs. Softmax vs. Linear comparison with $k=n=2$, $ \lambda \in [0.05, 1] $

# %%
load_prp_rrp_lam_comparison()

# %% [markdown]
# ### 2. Softmax beta comparison with $k=n=2$, $ \lambda \in [0.05, 1] $

# %%
load_softmax_beta_comparison()

# %% [markdown]
# ### 3. Linear slope (a) comparison with $k=n=2$, $ \lambda \in [0.05, 1] $

# %%
load_linear_slope_comparison()
