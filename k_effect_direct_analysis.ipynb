# %%
from utils.k_effect_direct_analysis_utils import *

# %% [markdown]
# ## Run simulations

# %%
run_prp_k_direct_comparison()

# %%
run_rrp_k_direct_comparison()

# %% [markdown]
# ## Results

# %% [markdown]
# ### 1. RRP $k$ comparison with $k \in [2, 10]$, $n=2$, $\lambda=0.5$

# %%
load_rrp_k_direct_comparison()

# %% [markdown]
# ### 2. PRP $k$ comparison with $k \in [2, 5]$, $n=2$, $\lambda=0.5$

# %%
load_prp_k_direct_comparison()
